# %%
import pandas as pd
import requests

df = pd.read_csv('https://ourworldindata.org/grapher/life-expectancy.csv?v=1&csvType=full&useColumnShortNames=true')

# %%
df[df['entity'].str.contains('UNI', case=False, regex=False)]
# Out:
#                              entity code  year  life_expectancy_0
# 15803                       Reunion  REU  1950            47.5602
# 15804                       Reunion  REU  1951            48.6476
# 15805                       Reunion  REU  1952            50.1082
# 15806                       Reunion  REU  1953            51.4650
# 15807                       Reunion  REU  1954            52.9912
# ...                             ...  ...   ...                ...
# 20581  United States Virgin Islands  VIR  2019            74.8761
# 20582  United States Virgin Islands  VIR  2020            74.7137
# 20583  United States Virgin Islands  VIR  2021            74.6132
# 20584  United States Virgin Islands  VIR  2022            75.0449
# 20585  United States Virgin Islands  VIR  2023            75.4724
#
# [666 rows x 4 columns]

# %%
df.dropna(subset=["code"], inplace=True)
df.isnull().sum()
# Out:
# entity               0
# code                 0
# year                 0
# life_expectancy_0    0
# dtype: int64

# %%
df.groupby("entity")["life_expectancy_0"].mean().sort_values(ascending=True)
# Out:
# entity
# USSR             32.700000
# South Sudan      37.841631
# Sierra Leone     43.189605
# Mali             43.760793
# Niger            44.187513
#                    ...
# Liechtenstein    76.288354
# Guernsey         76.995827
# Andorra          77.991046
# San Marino       77.997265
# Monaco           78.048231
# Name: life_expectancy_0, Length: 247, dtype: float64

# %%
df_2020 = df[df["year"] == 2020]

res = (
    df_2020
    .groupby("entity")["life_expectancy_0"]
    .mean()
    .sort_values(ascending=True)
)

res
# Out:
# entity
# Central African Republic    50.5959
# Nigeria                     53.0724
# Chad                        53.0818
# Lesotho                     55.1325
# Somalia                     57.0948
#                              ...
# Saint Barthelemy            84.0707
# Macao                       84.6100
# Japan                       84.6703
# Hong Kong                   84.7073
# Monaco                      86.0893
# Name: life_expectancy_0, Length: 246, dtype: float64

# %%
result =
